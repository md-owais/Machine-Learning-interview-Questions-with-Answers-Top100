# %% [markdown]
# # 1.	What is the difference between Parametric and Non Parametric Algorithms?

# %% [raw]
# 1. Difference Between Parametric and Non-Parametric Algorithms
# Detailed Explanation
# What are Parametric Algorithms?
#
# Parametric algorithms are machine learning algorithms that assume a fixed form for the function that maps input to output.
# They summarize the data using a fixed number of parameters, regardless of how large the dataset becomes.
#
# In simple words, these algorithms make assumptions about the data and then learn only a small set of values.
#
# Key idea
#
# They say:
#
# “I already assume the relationship looks like this. I only need to learn the parameters.”
#
# For example, in Linear Regression, we assume:
#
# 𝑦
# =
# 𝑚
# 𝑥
# +
# 𝑐
# y=mx+c
#
# Here:
#
# 𝑚
# m = slope
#
# 𝑐
# c = intercept
#
# No matter whether you have 100 rows or 10 lakh rows, the model still only learns these fixed parameters.
#
# Characteristics of Parametric Algorithms
#
# Fixed number of parameters
#
# Assumes a predefined model structure
#
# Simpler and faster to train
#
# Works well with smaller datasets
#
# Less flexible
#
# Can underfit if assumptions are incorrect
#
# Examples of Parametric Algorithms
# 1. Linear Regression
#
# Used when the relationship between variables is assumed to be linear.
#
# Example:
# Predicting salary based on years of experience.
#
# 2. Logistic Regression
#
# Used for classification problems.
# Even though its name says regression, it is mainly for classification.
#
# Example:
# Predicting whether an email is spam or not spam.
#
# 3. Naive Bayes
#
# Assumes independence among features.
#
# Example:
# Text classification, spam detection.
#
# Advantages of Parametric Algorithms
#
# Training is fast
#
# Less data needed
#
# Easy to understand and interpret
#
# Computationally efficient
#
# Disadvantages of Parametric Algorithms
#
# Strong assumptions may be wrong
#
# Less flexible
#
# Poor performance on complex patterns
#
# May underfit
#
# What are Non-Parametric Algorithms?
#
# Non-parametric algorithms do not assume a fixed functional form.
# Their complexity can grow as the amount of data grows.
#
# In simple words, these algorithms say:
#
# “I will learn the shape from the data itself instead of assuming it.”
#
# They are more flexible and can model complicated relationships.
#
# Characteristics of Non-Parametric Algorithms
#
# No fixed number of parameters
#
# Few assumptions about data
#
# More flexible
#
# Usually needs more data
#
# More computationally expensive
#
# Can overfit if not controlled
#
# Examples of Non-Parametric Algorithms
# 1. K-Nearest Neighbors (KNN)
#
# It stores the training data and predicts based on nearby points.
#
# Example:
# Classifying a fruit as apple or orange based on nearest known fruits.
#
# 2. Decision Tree
#
# Creates rules based on feature splits.
#
# Example:
# Loan approval based on salary, age, and credit score.
#
# 3. Random Forest
#
# Collection of many decision trees.
#
# 4. SVM with RBF kernel
#
# Kernel SVM can act as non-parametric because complexity depends on support vectors.
#
# Advantages of Non-Parametric Algorithms
#
# Flexible
#
# Can model complex nonlinear relationships
#
# Fewer assumptions
#
# Often better when data pattern is unknown
#
# Disadvantages of Non-Parametric Algorithms
#
# Slower training and prediction
#
# Needs more memory
#
# May overfit
#
# Usually needs more data
#
# Main Differences Table
# Feature	Parametric Algorithms	Non-Parametric Algorithms
# Model assumption	Strong assumptions	Few or no assumptions
# Parameters	Fixed	Can grow with data
# Flexibility	Less flexible	More flexible
# Training speed	Faster	Slower
# Data needed	Less	More
# Risk	Underfitting	Overfitting
# Examples	Linear Regression, Logistic Regression, Naive Bayes	KNN, Decision Tree, Random Forest
# Very Simple Beginner Language
# Parametric
#
# Parametric algorithms are like using a fixed-size box.
# You already decide the shape of the model first, then fit the data into it.
#
# Example:
# If you believe the data follows a straight line, you use Linear Regression.
#
# So parametric means:
#
# fixed structure
#
# fixed parameters
#
# simple and fast
#
# Non-Parametric
#
# Non-parametric algorithms are like flexible clay.
# They do not assume a fixed shape. They learn the shape from data.
#
# Example:
# Decision Tree keeps splitting based on what data says.
#
# So non-parametric means:
#
# flexible structure
#
# grows with data
#
# can learn complex patterns
#
# Real-Life Analogy
# Parametric
#
# Like buying a ready-made shirt: S, M, L, XL.
# The sizes are fixed.
#
# Non-Parametric
#
# Like going to a tailor and getting a custom shirt made exactly for your body.
#
# Interview Answer in 5 Lines
#
# Parametric algorithms assume a fixed model structure and learn a fixed number of parameters. They are faster, simpler, and work well on smaller datasets, but may underfit if assumptions are wrong. Non-parametric algorithms do not assume a fixed structure and become more flexible as data increases. They can capture complex patterns but usually require more data and computation. Examples are Linear Regression for parametric and KNN or Decision Tree for non-parametric.
#
# Graph-Style Intuition
#
# Imagine data points on a graph:
#
# Parametric
#
# You try to fit a straight line or another fixed curve through the points.
#
# Example:
# A single line tries to represent all points.
#
# Non-Parametric
#
# You allow the model to bend and adapt to the exact shape of the data.
#
# Example:
# A decision boundary can be curved, irregular, and data-driven.
#
# Python Example
# Parametric Example: Linear Regression
# from sklearn.linear_model import LinearRegression
# import numpy as np
#
# # Sample data
# X = np.array([[1], [2], [3], [4], [5]])
# y = np.array([2, 4, 6, 8, 10])
#
# model = LinearRegression()
# model.fit(X, y)
#
# print("Slope:", model.coef_)
# print("Intercept:", model.intercept_)
# print("Prediction for 6:", model.predict([[6]]))
#
# Non-Parametric Example: KNN
# from sklearn.neighbors import KNeighborsClassifier
# import numpy as np
#
# # Sample data
# X = np.array([[1], [2], [3], [6], [7], [8]])
# y = np.array([0, 0, 0, 1, 1, 1])
#
# model = KNeighborsClassifier(n_neighbors=3)
# model.fit(X, y)
#
# print("Prediction for 5:", model.predict([[5]]))

# %%
# Parametric Example: Linear Regression
from sklearn.linear_model import LinearRegression
import numpy as np

# Sample data
X = np.array([[1], [2], [3], [4], [5]])
y = np.array([2, 4, 6, 8, 10])

model = LinearRegression()
model.fit(X, y)

print("Slope:", model.coef_)
print("Intercept:", model.intercept_)
print("Prediction for 6:", model.predict([[6]]))
# Out:
# Slope: [2.]
# Intercept: -1.7763568394002505e-15
# Prediction for 6: [12.]

# %%
# Non-Parametric Example: KNN
from sklearn.neighbors import KNeighborsClassifier
import numpy as np

# Sample data
X = np.array([[1], [2], [3], [6], [7], [8]])
y = np.array([0, 0, 0, 1, 1, 1])

model = KNeighborsClassifier(n_neighbors=3)
model.fit(X, y)

print("Prediction for 5:", model.predict([[5]]))
# Out:
# Prediction for 5: [1]

# %% [raw]
# Final Quick Revision
# Parametric vs Non-Parametric
#
# Parametric = fixed form, fixed parameters, faster, less flexible
#
# Non-parametric = flexible form, grows with data, slower, more flexible
#
# Super Short Interview Revision
# 1. Parametric vs Non-Parametric
#
# Parametric algorithms assume a fixed model structure and fixed number of parameters, while non-parametric algorithms do not assume a fixed structure and can grow with data. Parametric models are faster and simpler, whereas non-parametric models are more flexible but computationally expensive.
