# %% [raw]
# 🔹 1. Types of Naive Bayes
# 📌 1) Gaussian Naive Bayes
# 👉 When to use
#
# When features are continuous numerical values
#
# Assumes data follows a normal (Gaussian) distribution
#
# 📊 Assumption
#
# Each feature is distributed like a bell curve.
#
# P(x|y) = 1/root(2*pi*sigma**2)e
#
# P(x∣y)=2πσ2
# ​1​e−2σ2(x−μ)2​
#
# 🧠 Example
#
# Predicting disease based on:
#
# age
#
# blood pressure
#
# cholesterol level
#
# All are continuous → use Gaussian NB
#
# 📌 2) Multinomial Naive Bayes
# 👉 When to use
#
# When features represent counts or frequencies
#
# Mostly used in text data
#
# 📊 Assumption
#
# Data represents counts (like word frequency).
#
# 🧠 Example
#
# Spam detection:
#
# “free” appears 3 times
#
# “offer” appears 2 times
#
# Feature = count of words
#
# ✔ Very common in:
#
# NLP
#
# Document classification
#
# Email spam detection
#
# 📌 3) Bernoulli Naive Bayes
# 👉 When to use
#
# When features are binary (0 or 1)
#
# 📊 Assumption
#
# Only checks presence or absence of feature
#
# 🧠 Example
#
# Spam detection:
#
# “free” present → 1
#
# “offer” absent → 0
#
# ✔ Difference from Multinomial:
#
# Multinomial → counts
#
# Bernoulli → presence/absence
#
# 🔥 Quick Comparison
# Type	Data Type	Example
# Gaussian NB	Continuous	age, salary
# Multinomial NB	Count data	word frequency
# Bernoulli NB	Binary data	word present/absent
# 🔹 2. Python Implementation + Real Dataset Example
#
# Let’s use a simple dataset from sklearn (Iris dataset).

# %%
# Gaussian Naive Bayes Example
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# Load dataset
data = load_iris()
X = data.data
y = data.target

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Model
model = GaussianNB()
model.fit(X_train, y_train)

# Prediction
y_pred = model.predict(X_test)

# Accuracy
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9333333333333333

# %%
# Multinomial Naive Bayes (Text Example)
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB

# Sample data
texts = ["free offer now", "win money now", "hello friend", "meeting tomorrow"]
labels = [1, 1, 0, 0]  # 1 = spam, 0 = not spam

# Convert text to count vectors
vectorizer = CountVectorizer()
X = vectorizer.fit_transform(texts)

# Model
model = MultinomialNB()
model.fit(X, labels)

# Prediction
test = vectorizer.transform(["free money"])
print(model.predict(test))
# Out:
# [1]

# %%
# Bernoulli Naive Bayes
from sklearn.naive_bayes import BernoulliNB

# Using same text data but binary features
vectorizer = CountVectorizer(binary=True)
X = vectorizer.fit_transform(texts)

model = BernoulliNB()
model.fit(X, labels)

test = vectorizer.transform(["free money"])
print(model.predict(test))
# Out:
# [1]

# %% [raw]
# 3. Interview Tricky Follow-up Questions
#
# Here are important follow-ups 👇
#
# ❓ 1. Why does Naive Bayes work even if independence assumption is wrong?
# ✅ Answer
#
# Even though features are not independent, Naive Bayes often works well because:
#
# It focuses on relative probability comparison
#
# Errors cancel out in many cases
#
# Works well in high-dimensional data (like text)
#
# ❓ 2. When will Naive Bayes perform poorly?
# ✅ Answer
#
# When features are highly dependent
#
# When data is very small
#
# When probability assumption is far from reality
#
# ❓ 3. Difference between Multinomial and Bernoulli NB?
# ✅ Answer
#
# Multinomial → uses frequency/count
#
# Bernoulli → uses binary presence/absence
#
# ❓ 4. Why is Naive Bayes so fast?
# ✅ Answer
#
# No complex optimization (like gradient descent)
#
# Uses simple probability calculations
#
# Works directly on counts/statistics
#
# ❓ 5. What is Laplace Smoothing?
# ✅ Answer
#
# Used to handle zero probability problem.
#
# P = count+1/total+N
#
# Prevents probability from becoming zero.
#
# ❓ 6. Can Naive Bayes be used for continuous data?
# ✅ Answer
#
# Yes — using Gaussian Naive Bayes
#
# ❓ 7. Is Naive Bayes a generative or discriminative model?
# ✅ Answer
#
# 👉 It is a generative model
# Because it models:
#
# P(X∣Y) and P(Y)
#
# ❓ 8. Why is Naive Bayes good for NLP?
# ✅ Answer
#
# Works well with high-dimensional sparse data
#
# Fast training
#
# Handles large vocabulary efficiently
#
# 🎯 Final Interview Summary
#
# Naive Bayes has three main types: Gaussian for continuous data, Multinomial for count-based data like text, and Bernoulli for binary features. It is widely used due to its simplicity and efficiency. Despite its strong independence assumption, it performs well in many real-world problems, especially NLP. It is easy to implement and computationally fast, making it a good baseline model.
#
# ⚡ One-line Memory Trick
#
# Gaussian → continuous
#
# Multinomial → counts
#
# Bernoulli → binary
